# %%
import sagemaker
from sagemaker import get_execution_role
import boto3
import pandas as pd
import awswrangler as wr

# %%
pip install awswrangler
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.3/255.3 KB 1.8 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 KB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 KB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.1/112.1 KB 27.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.7/214.7 KB 31.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 KB 19.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 55.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.5/131.5 KB 34.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 KB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 KB 23.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: asn1crypto
# ...

# %%
train = wr.s3.read_csv(path='s3://bucket-to-snowflake/ml_train.csv.gz', compression='gzip')

# %%
train
# Out:
#           809799  155035  train   4  13944  1  4.1  248  1.1
# 0         809799  155035  train   4  22389  0    4    5    1
# 1         809799  155035  train   4  29576  0    4    2    1
# 2         809799  155035  train   4  26372  0    4   37    1
# 3        2089846  155038  train  12  29928  1    5   18    1
# 4        2089846  155038  train  12  46576  1    5    4    1
# ...          ...     ...    ...  ..    ... ..  ...  ...  ...
# 1084610  2546866  155029  train  17   3048  1   12    8    1
# 1084611  2546866  155029  train  17  34702  1   12   23    1
# 1084612  2546866  155029  train  17  13920  0   12   46    1
# 1084613  2546866  155029  train  17   7326  0   12   26    1
# 1084614  2546866  155029  train  17   8638  1   12  154    1
#
# [1084615 rows x 9 columns]
